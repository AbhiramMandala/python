# %%
res=10/0
print(res)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 res=10/0
#       2 print(res)
#
# ZeroDivisionError: division by zero

# %%
#Contain Runtime Error===   Logic mistake
try:
    x,y=10,0
    print(x/y)
except ZeroDivisionError:
    print("ZeroDivisionError:")
except Exception as e:
    print("ZeroDivisionError",e)
# Out:
# ZeroDivisionError:

# %%
#Contain Runtime Error===   Logic mistake
try:
    x,y=10,0
    print(x/y)
except:
    print("ZeroDivisionError")
# Out:
# ZeroDivisionError:

# %%
try:
    x,y=10,0
    print(x/y)
except:
    print("ZeroDivisionError")
else:
    print("Program done")
# Out:
# ZeroDivisionError

# %%
try:
    x,y=10,2
    print(x/y)
except:
    print("ZeroDivisionError")
else:
    print("Program done")
# Out:
# 5.0
# Program done

# %%
try:
    x,y=10,0
    print(x/y)
except:
    print("ZeroDivisionError")
else:
    print("Program done")
finally:
    print("This block always executes")
# Out:
# ZeroDivisionError
# This block always executes

# %%
try:
    x,y=10,2
    print(x//y)
except:
    print("ZeroDivisionError")
else:
    print("Program done")
finally:
    print("This block always executes")
# Out:
# 5
# Program done
# This block always executes

# %%
try:
    print(res)
except ZeroDivisionError:
    print("ZeroDivisionError:")
except NameError:
    print("Name is not defined")
except Exception as e:
    print("ZeroDivisionError",e)
# Out:
# Name is not defined

# %%
try:
    num=10
    num.append(100)
    print(res)
except ZeroDivisionError:
    print("ZeroDivisionError:")
except NameError:
    print("Object is not defined")
except Exception as e:
    print(e)
# Out:
# 'int' object has no attribute 'append'

# %%
try:
    num=10
    num.append(100)
except (ZeroDivisionError,AttributeError) as e:
    print("This except handles both ZeroDivision and Attribute Error")
except NameError:
    print("Object is not defined")
except Exception as e:
    print(e)
# Out:
# This except handles both ZeroDivision and Attribute Error

# %%
try:
    num=[10,20]
    n=num[10]
    print(n)
except (ZeroDivisionError,AttributeError) as e:
    print("This except handles both ZeroDivision and Attribute Error")
except NameError:
    print("Object is not defined")
except IndexError:
    print("This block handlea the index Error")
except Exception as e:
    print(e)
# Out:
# This block handlea the index Error
