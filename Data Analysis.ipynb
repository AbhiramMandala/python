# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#table info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.describe(exclude='int')
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['furnishingstatus']
# Out:
# 0           furnished
# 1           furnished
# 2      semi-furnished
# 3           furnished
# 4           furnished
#             ...
# 540       unfurnished
# 541    semi-furnished
# 542       unfurnished
# 543         furnished
# 544       unfurnished
# Name: furnishingstatus, Length: 545, dtype: object

# %%
df[['price','furnishingstatus','bathrooms']]
# Out:
#         price furnishingstatus  bathrooms
# 0    13300000        furnished          2
# 1    12250000        furnished          4
# 2    12250000   semi-furnished          2
# 3    12215000        furnished          2
# 4    11410000        furnished          1
# ..        ...              ...        ...
# 540   1820000      unfurnished          1
# 541   1767150   semi-furnished          1
# 542   1750000      unfurnished          1
# 543   1750000        furnished          1
# 544   1750000      unfurnished          1
#
# [545 rows x 3 columns]

# %%
df.bedrooms.value_counts()
# Out:
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
#how many main road houses are there
df.mainroad.value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
df.basement.value_counts()
# Out:
# basement
# no     354
# yes    191
# Name: count, dtype: int64

# %%
df.furnishingstatus.value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
categorical_cloumns=['guestroom','basement','hotwaterheating','airconditioning','parking', 'prefarea', 'furnishingstatus']

# %%
df.guestroom.replace({'yes':1,'no':0},inplace=True)
df.guestroom
# Out:
# C:\Users\M.Sadashiv\AppData\Local\Temp\ipykernel_14472\1285383832.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.guestroom.replace({'yes':1,'no':0},inplace=True)
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: guestroom, Length: 545, dtype: int64

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad  guestroom basement  \
# 0  13300000  7420         4          2        3      yes          0       no
# 1  12250000  8960         4          4        4      yes          0       no
# 2  12250000  9960         3          2        2      yes          0      yes
# 3  12215000  7500         4          2        2      yes          0      yes
# 4  11410000  7420         4          1        2      yes          1      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.guestroom.replace({'yes':1,'no':0},inplace=True)
df.mainroad.replace({'yes':1,'no':0},inplace=True)
df.basement.replace({'yes':1,'no':0},inplace=True)
df.hotwaterheating.replace({'yes':1,'no':0},inplace=True)
df.airconditioning.replace({'yes':1,'no':0},inplace=True)
df.prefarea.replace({'yes':1,'no':0},inplace=True)
df.furnishingstatus.replace({'furnished':2,'semi-furnished':1,'unfurnished':0},inplace=True)
# Out:
# C:\Users\M.Sadashiv\AppData\Local\Temp\ipykernel_14472\116903784.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.furnishingstatus.replace({'furnished':2,'semi-furnished':1,'unfurnished':0},inplace=True)

# %%
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000   7420         4          2        3         1          0
# 1  12250000   8960         4          4        4         1          0
# 2  12250000   9960         3          2        2         1          0
# 3  12215000   7500         4          2        2         1          0
# 4  11410000   7420         4          1        2         1          1
# 5  10850000   7500         3          3        1         1          0
# 6  10150000   8580         4          3        4         1          0
# 7  10150000  16200         5          3        2         1          0
# 8   9870000   8100         4          1        2         1          1
# 9   9800000   5750         3          2        4         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# ...

# %%
#duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
#find null values in table
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(25,5))
sns.lineplot(data=df,x='price',y='bedrooms')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.barplot(data=df,x='bedrooms',y='furnishingstatus',hue='parking')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.barplot(data=df,x='bedrooms',y='mainroad',hue='parking')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.kdeplot(data=df,x='bedrooms',y='mainroad')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.kdeplot(data=df,x='guestroom',y='mainroad')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.catplot(data=df,x='bedrooms',y='mainroad',hue='parking')
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(data=df,x='bedrooms',hue='parking',native_scale=True)
plt.show()
