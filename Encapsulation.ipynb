# %%
#Encapulation
class Bank:
    def __init__(self,name,age,amount):
        self.name=name #Public Attribute
        self._age=age  #protected Attribute
        self.__amount=amount   #private Attribute
    def get_balance(self):
        return f"Current balance is {self.__amount}"
    def withdraw(self,withdraw_amount):
        if self.__amount>=withdraw_amount:
            self.__amount -=withdraw_amount
            return f"withdraw is successful and current balance is {self.__amount}"
    def _totalUser(self):   #Protrcted Method
        return "Total users in bank"
    def __total_amount(self):   #private Method
        return "Total amount in bank"
b=Bank("Gita",15,10000)
b.get_balance()
print(b.withdraw(100))

print(b._age) #Protected member access in out of class
print(b._Bank__amount ) #private memeber in out of class
print(b._totalUser())
print(b._Bank__total_amount())   #name mangling : instance._className__attributeName
# Out:
# withdraw is successful and current balance is 9900
# 15
# 9900
# Total users in bank
# Total amount in bank

# %%
from bank import Bank
b=Bank("ravi",10,10000)
print(b.get_balance())
# Out:
# Current balance is 10000
